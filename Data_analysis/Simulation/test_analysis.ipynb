# %%
import matplotlib.pyplot as plt

from General.Data_handling.ComsolAnalyzer import Comsol1DAnalyzer

loc = r'C:\Users\20222772\Downloads\Export.txt'
imported = Comsol1DAnalyzer(loc)

# %%
plt.plot(imported._times, imported.data['V0*Square(t) [V]'].T[0])
plt.xlabel('Time [s]')
plt.ylabel('Voltage [V]')
plt.savefig(r'C:\Users\20222772\Downloads\Voltage.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.plot(imported._times, imported.data['V0*Square(t) [V]'].T[0])
#       2 plt.xlabel('Time [s]')
#       3 plt.ylabel('Voltage [V]')
#
# KeyError: 'V0*Square(t) [V]'

# %%
plt.rcParams.update({'font.size': 14})
imported.var_vs_time('ne', order=1, cbarticks=True, show=False)
plt.savefig(r'C:\Users\20222772\Downloads\ne.png', dpi=300)
plt.show()
imported.var_vs_time('Te', order=1)
plt.savefig(r'C:\Users\20222772\Downloads\Te.png', dpi=300)
imported.var_vs_time('Ars', order=1)
plt.savefig(r'C:\Users\20222772\Downloads\Ars.png', dpi=300)
imported.var_vs_time('Ar$^{1+}$', order=1)
plt.savefig(r'C:\Users\20222772\Downloads\Ar+.png', dpi=300)
imported.var_vs_time('V', order=1)
plt.savefig(r'C:\Users\20222772\Downloads\V.png', dpi=300)
imported.diff_var_vs_time(('Ar$^{1+}$', 'ne'))
plt.savefig(r'C:\Users\20222772\Downloads\Charge.png', dpi=300)
