# %%
import numpy as np
import matplotlib.pyplot as plt

from General.Analysis import Analyzer
from General.Data_handling import import_hdf5, drive_letter
from General.Data_handling.Import import DataSet

dependent = 'NO3-'
variable_name = 'NO3 [mM]'
variable_factor = 1000
wavelength_range = [180, 450]
r2_values = [0.99, 1]
wavelength_plot_every = 5
plot_measurement_num = 2
baseline_correction = [450, 500]

image_loc = rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Plots\Calibration\NO3'
loc = rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Measurements\Calibration\NO3 cuvette\data.hdf5'
dat = import_hdf5(loc, dependent)
analyzer = Analyzer.from_DataSet(DataSet.from_simple(dat, wavelength_range, plot_measurement_num, baseline_correction), variable_factor, variable_name, 'turbo')

analyzer2 = Analyzer.from_DataSet(DataSet.from_simple(import_hdf5(rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Measurements\Calibration\NO3\data.hdf5', dependent), wavelength_range, plot_measurement_num, baseline_correction), variable_factor, variable_name, 'turbo')

# %%
analyzer.absorbance_vs_wavelength_with_variable(save_loc=image_loc)
plt.show()
analyzer.absorbance_vs_wavelength_with_variable(save_loc=image_loc, save_suffix=' zoom',
                                                plot_kwargs={'ylim': [-0.005, 0.005]})
plt.show()

analyzer2.absorbance_vs_wavelength_with_variable(plot_kwargs={'ylim': [-0.005, 0.005]})

# %%
analyzer.pearson_r_vs_wavelength_with_methods(save_loc=image_loc)
analyzer.pearson_r_vs_wavelength_with_methods(save_loc=image_loc, save_suffix=' zoom', r2_values=r2_values)

# %%
analyzer.full_spectrum_fit_with_methods()
# Out:
#         # Fit report
#         corrected: 621.146 ± 0.092
#         corrected num: 622.829 ± 0.152
#         corrected best num: 506.112 ± 0.137
#         uncorrected: 620.758 ± 0.100
#         uncorrected num: 620.852 ± 0.186
#         uncorrected best num: 506.226 ± 0.138
