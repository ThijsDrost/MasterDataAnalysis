# %%
import matplotlib.pyplot as plt

from Calibrations.Calibration_analysis import Analyzer
from Data_handling.Import import DataSet, import_hdf5, drive_letter

dependent = 'NO2-'
variable_name = 'NO2 [mM]'
variable_factor = 1000
wavelength_range = [180, 450]
r2_values = [0.99, 1]
wavelength_plot_every = 5
plot_measurement_num = 2
baseline_correction = [450, 500]

image_loc = rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Plots\Calibration\NO2'
loc = rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Measurements\Calibration\NO2 cuvette\data.hdf5'
dat = import_hdf5(loc, dependent)
analyzer = Analyzer.from_DataSet(DataSet.from_simple(dat, wavelength_range, plot_measurement_num, baseline_correction), variable_factor, variable_name, 'turbo')

baseline_correction = [500, 550]
analyzer2 = Analyzer.from_DataSet(DataSet.from_simple(import_hdf5(rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Measurements\Calibration\NO2 (1)\data.hdf5', dependent), wavelength_range, 1, baseline_correction), variable_factor, variable_name, 'turbo')
analyzer3 = Analyzer.from_DataSet(DataSet.from_simple(import_hdf5(rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Measurements\Calibration\NO2 (2)\data.hdf5', dependent), wavelength_range, 1, baseline_correction), variable_factor, variable_name, 'turbo')

# %%
analyzer.absorbance_vs_wavelength_with_variable(save_loc=image_loc)
plt.show()
analyzer.absorbance_vs_wavelength_with_variable2(show=True)


analyzer.absorbance_vs_wavelength_with_variable(save_loc=image_loc, save_suffix=' zoom',
                                                plot_kwargs={'ylim': [-0.005, 0.01]})
plt.show()
analyzer2.absorbance_vs_wavelength_with_variable()
plt.show()
analyzer2.absorbance_vs_wavelength_with_variable(plot_kwargs={'ylim': [-0.005, 0.01]})
plt.show()

# %%
analyzer.pearson_r_vs_wavelength_with_methods(save_loc=image_loc)
analyzer.pearson_r_vs_wavelength_with_methods(save_loc=image_loc, save_suffix=' zoom', r2_values=r2_values)

# %%
analyzer.full_spectrum_fit_with_methods()
# Out:
#         # Fit report
#         corrected: 505.418 ± 0.075
#         corrected num: 503.133 ± 0.091
#         corrected best num: 503.731 ± 0.088
#         uncorrected: 499.639 ± 0.156
#         uncorrected num: 501.116 ± 0.148
#         uncorrected best num: 502.592 ± 0.113
