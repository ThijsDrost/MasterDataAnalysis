# %%
import numpy as np
import matplotlib.pyplot as plt

from Calibrations.Calibration_analysis import Analyzer
from Data_handling.Import import DataSet, import_hdf5, drive_letter

dependent = 'H2O2'
variable_name = 'H2O2 [mM]'
variable_factor = 1000
wavelength_range = [180, 450]
r2_values = [0.99, 1]
wavelength_plot_every = 5
plot_measurement_num = 2
baseline_correction = [450, 500]

image_loc = rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Plots\Calibration\H2O2'
loc = rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Measurements\Calibration\H2O2 cuvette\data.hdf5'
dat = import_hdf5(loc, dependent)
analyzer = Analyzer.from_DataSet(DataSet.from_simple(dat, wavelength_range, plot_measurement_num, baseline_correction), variable_factor, variable_name, 'turbo')

baseline_correction = [500, 550]
analyzer2 = Analyzer.from_DataSet(DataSet.from_simple(import_hdf5(rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Measurements\Calibration\H2O2 (1)\data.hdf5', dependent), wavelength_range, 1, baseline_correction), variable_factor, variable_name, 'turbo')
analyzer3 = Analyzer.from_DataSet(DataSet.from_simple(import_hdf5(rf'{drive_letter()}:\OneDrive - TU Eindhoven\Master thesis\Measurements\Calibration\H2O2 (2)\data.hdf5', dependent), wavelength_range, 1, baseline_correction), variable_factor, variable_name, 'turbo')

# %%
analyzer.absorbance_vs_wavelength_with_variable(save_loc=image_loc)
plt.show()
analyzer.absorbance_vs_wavelength_with_variable(save_loc=image_loc, save_suffix=' zoom', plot_kwargs={'ylim': [-0.005, 0.01]}, legend_kwargs= {'loc':'center left', 'bbox_to_anchor':(1, 0.5)})
plt.show()
analyzer2.absorbance_vs_wavelength_with_variable()
plt.show()
analyzer2.absorbance_vs_wavelength_with_variable(plot_kwargs={'ylim': [-0.005, 0.01]})
plt.show()
analyzer.absorbance_vs_variable_with_bunched_wavelength(10, True, min_absorbance=0.001)
plt.show()
analyzer.absorbance_vs_variable_with_bunched_wavelength(10, False, min_absorbance=0.001)
plt.show()

# %%
analyzer.pearson_r_vs_wavelength_with_methods(save_loc=image_loc, plot_kwargs={'ylim': [0.5, 1.005]})
analyzer.pearson_r_vs_wavelength_with_methods(save_loc=image_loc, save_suffix=' zoom', r2_values=r2_values)

# %%
analyzer.full_spectrum_fit_with_methods()
# Out:
#         # Fit report
#         corrected: 499.659 ± 0.095
#         corrected num: 501.020 ± 0.162
#         corrected best num: 501.677 ± 0.163
#         uncorrected: 497.549 ± 0.130
#         uncorrected num: 498.529 ± 0.208
#         uncorrected best num: 496.849 ± 0.260
