# %%
import numpy as np
import matplotlib.pyplot as plt

from Calibration_analysis import Analyzer
from Data_handling.Import import DataSet, import_hdf5

save_loc = 
loc1 = r'D:\OneDrive - TU Eindhoven\Master thesis\Measurements\Calibration\H2O2 pH\data.hdf5'
dat1 = import_hdf5(loc1, 'pH')
analyzer1 = Analyzer.from_DataSet(DataSet.from_simple(dat1, [190, 450], 3, [350, 400]), 1, 'pH', 'jet')
loc2 = r'D:\OneDrive - TU Eindhoven\Master thesis\Measurements\Calibration\H2O2 pH 2\data.hdf5'
dat2 = import_hdf5(loc2, 'pH')
analyzer2 = Analyzer.from_DataSet(DataSet.from_simple(dat2, [190, 450], 3, [350, 400]), 1, 'pH', 'jet')
# Out:
# [350, 400]
# [350, 400]
# [350, 400]
# [350, 400]

# %%
analyzer1.absorbance_vs_wavelength_with_variable(save_loc=)
plt.show()

analyzer2.absorbance_vs_wavelength_with_variable()
plt.show()

Analyzer.from_DataSet(DataSet.from_simple(dat1 + dat2, [190, 450], 3, [350, 400]), 1, 'pH', 'jet').absorbance_vs_wavelength_with_variable()
plt.show()

Analyzer.from_DataSet(DataSet.from_simple(dat1 + dat2, [190, 450], 3, [350, 400]), 1, 'pH', 'jet').absorbance_vs_wavelength_with_variable()
plt.xlim(195, 250)
plt.ylim(0, 0.2)
plt.show()
# Out:
# [350, 400]
# [350, 400]
# [350, 400]
# [350, 400]
